# %%
import scGCO
import time
import pandas as pd
import numpy as np
# %load_ext memory_profiler

# %%
ff='/simulate/Data/1_million_cells_100genes_counts0.csv'
#ww='/media/covo/SamSung/wanwan/sim/100051cells_step_counts.csv'
# %memit data0 = pd.read_csv(ff, sep=',', index_col = 0,iterator=True)
i=100
data=data0.get_chunk(i)
# Out:
# peak memory: 142.63 MiB, increment: 2.49 MiB

# %%
data.iloc[:10,:10]
# Out:
#                                        step_1  step_2  step_3  step_4  step_5  \
# 0.410693558864295x0.674942613113672         1       7       2       1      10
# 0.104294288204983x0.498498122673482         1       7       2       1      10
# 0.814270022092387x0.497975082369521        45       7      44       1      23
# 0.854365968843922x0.0149538014084101       45       7      44       1      23
# 0.0314666354097426x0.0387805758509785       1       7       2       1      10
# 0.580545703647658x0.0884250258095562       45       7      44       1      23
# 0.139289037091658x0.591163544449955         1       7       2       1      10
# 0.692090896191075x0.249520175391808        45       7      44       1      23
# 0.985326251480728x0.955651937285438        45       7      44       1      23
# 0.674204571638256x0.808533543720841        45       7      44       1      23
#
#                                        step_6  step_7  step_8  step_9  step_10
# 0.410693558864295x0.674942613113672         2       8       9       1        5
# 0.104294288204983x0.498498122673482         2       8       9       1        5
# 0.814270022092387x0.497975082369521         2      21       9      24        5
# 0.854365968843922x0.0149538014084101        2      21       9      24        5
# 0.0314666354097426x0.0387805758509785       2       8       9       1        5
# 0.580545703647658x0.0884250258095562        2      21       9      24        5
# 0.139289037091658x0.591163544449955         2       8       9       1        5
# 0.692090896191075x0.249520175391808         2      21       9      24        5
# 0.985326251480728x0.955651937285438         2      21       9      24        5
# 0.674204571638256x0.808533543720841         2      21       9      24        5

# %%
data.shape
# Out:
# (100, 100)

# %%
temp = [val.split('x') for val in data.index.values]
coord = np.array([[float(a[0]), float(a[1])] for a in temp])

locs=coord
sub_data=data
sub_data = sub_data.loc[:,(sub_data != 0).astype(int).sum(axis=0) >= 10]    
data_norm = scGCO.normalize_count_cellranger(sub_data)

factor_df, size_factor = scGCO.estimate_smooth_factor(locs, data_norm)

start = time.time()
# %memit result_df = scGCO.identify_spatial_genes(locs, data_norm, size_factor)
end = time.time()
t=end-start
# Out:
#   0%|          | 0/8 [00:00<?, ?it/s]/home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# ...
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# 100%|██████████| 8/8 [00:00<00:00,  8.03it/s]
# peak memory: 149.95 MiB, increment: 1.57 MiB

# %%
nc=[]
tt =[]
import time

# %%
#n_cell=[500000,1000000]
n_cell=[100,250,500,1000,1500,2500,5000,10000,15000]
#n_cell=[1000,1500]
for i in n_cell:
    ff='simulate/Data/100genes_'+str(i)+'cells.csv'
    #data0 = pd.read_csv(ff, sep=',', index_col = 0,iterator=True)
    #data=data0.get_chunk(i)
    data=pd.read_csv(ff,sep=',',index_col=0)
    
    temp = [val.split('x') for val in data.index.values]
    coord = np.array([[float(a[0]), float(a[1])] for a in temp])

    locs=coord
    sub_data=data
    sub_data = sub_data.loc[:,(sub_data != 0).astype(int).sum(axis=0) >= 10]    
    data_norm = scGCO.normalize_count_cellranger(sub_data)

    factor_df, size_factor = scGCO.estimate_smooth_factor(locs, data_norm)

    start = time.time()
    # %memit result_df = scGCO.identify_spatial_genes(locs, data_norm, size_factor)
    end = time.time()
    t=end-start
    
    nc.append(int(i))
    tt.append(t)
# Out:
#   0%|          | 0/8 [00:00<?, ?it/s]/home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
#  38%|███▊      | 3/8 [00:02<00:03,  1.49it/s]/home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# ...
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
#  12%|█▎        | 1/8 [03:50<26:51, 230.27s/it]/home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /home/covo/anaconda3/envs/py3+R/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return_n_iter=True)
# 100%|██████████| 8/8 [05:09<00:00, 84.82s/it]
# peak memory: 457.63 MiB, increment: 188.55 MiB

# %%
nc
# Out:
# [100, 250, 500, 1000, 1500, 2500, 5000, 10000, 15000, 50000, 100000]

# %%
memory

# %%
df=pd.DataFrame({'n.cells':nc,'n.genes':100,'time_s':tt})

# %%
df.to_excel('simulate/Result/scGCO_100gene.xls')

# %%
df
# Out:
#     n.cells  n.genes      time_s
# 0       100      100    1.239886
# 1       250      100    2.175632
# 2       500      100    3.534748
# 3      1000      100    6.851990
# 4      1500      100    9.589642
# 5      2500      100   17.732561
# 6      5000      100   35.699097
# 7     10000      100   65.739392
# 8     15000      100  102.837043
# 9     50000      100  330.502859
# 10   100000      100  675.598512
